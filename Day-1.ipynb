# %% [markdown]
# ## Day - 1: The XOR Problem

# %%
# !pip3 install numpy matplotlib scikit-learn

# %%
# !pip3 install tensorflow

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.neural_network import MLPClassifier
from mpl_toolkits.mplot3d import Axes3D
from sklearn.metrics import accuracy_score
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.optimizers import SGD
# Out:
# 2025-04-17 11:02:06.999841: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2025-04-17 11:02:07.314702: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2025-04-17 11:02:07.318596: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-04-17 11:02:08.372757: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
np.random.seed(42)
tf.random.set_seed(42)

# %%
# Standard 2D XOR data
def generate_xor_data(n_samples=100, noise=0.1, dim=2):
    if dim < 2:
        raise ValueError("Dimension must be at least 2")
    X = np.random.rand(n_samples, dim)
    y = np.logical_xor(X[:, 0] > 0.5, X[:, 1] > 0.5).astype(int)
    if noise > 0:
        flip_indices = np.random.choice(n_samples, int(noise * n_samples), replace=False)
        y[flip_indices] = 1 - y[flip_indices]
    
    return X, y
X_2d, y_2d = generate_xor_data(n_samples=200, noise=0.05, dim=2)

# %%
plt.figure(figsize=(10, 8))
plt.scatter(X_2d[y_2d == 0, 0], X_2d[y_2d == 0, 1], c='blue', marker='o', label='Class 0')
plt.scatter(X_2d[y_2d == 1, 0], X_2d[y_2d == 1, 1], c='red', marker='x', label='Class 1')
plt.xlabel('X₁')
plt.ylabel('X₂')
plt.title('2D XOR Problem')
plt.legend()
plt.grid(True)
plt.show()

# %%
def plot_decision_boundary(model, X, y, title):
    # mesh grid creation
    h = 0.02
    x_min, x_max = X[:, 0].min() - 0.1, X[:, 0].max() + 0.1
    y_min, y_max = X[:, 1].min() - 0.1, X[:, 1].max() + 0.1
    xx, yy = np.meshgrid(np.arange(x_min, x_max, h), np.arange(y_min, y_max, h))

    Z = model.predict(np.c_[xx.ravel(), yy.ravel()])
    Z = Z.reshape(xx.shape)
    
    # Decision boundary
    plt.figure(figsize=(10, 8))
    plt.contourf(xx, yy, Z, alpha=0.3)
    plt.scatter(X[y == 0, 0], X[y == 0, 1], c='blue', marker='o', label='Class 0')
    plt.scatter(X[y == 1, 0], X[y == 1, 1], c='red', marker='x', label='Class 1')
    plt.xlabel('X₁')
    plt.ylabel('X₂')
    plt.title(title)
    plt.legend()
    plt.grid(True)
    plt.show()

# %% [markdown]
# ### Approach 1: Single-layer perceptron (linear model)

# %%
def linear_model():
    model = Sequential([
        Dense(1, activation='sigmoid', input_shape=(2,))
    ])
    model.compile(optimizer=SGD(learning_rate=0.1), loss='binary_crossentropy', metrics=['accuracy'])
    model.fit(X_2d, y_2d, epochs=100, verbose=0)
    return model

linear_model_xor = linear_model()
linear_predictions = (linear_model_xor.predict(X_2d) > 0.5).astype(int).flatten()
linear_accuracy = accuracy_score(y_2d, linear_predictions)
print(f"Linear model accuracy: {linear_accuracy:.4f}")

plot_decision_boundary(linear_model_xor, X_2d, y_2d, f"Linear Model Decision Boundary (Accuracy: {linear_accuracy:.4f})")
# Out:
# 2025-04-17 11:02:09.686195: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2025-04-17 11:02:09.923264: W tensorflow/core/common_runtime/gpu/gpu_device.cc:1960] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...
# 7/7 [==============================] - 0s 969us/step
# Linear model accuracy: 0.5500
# 113/113 [==============================] - 0s 621us/step

# %% [markdown]
# ### Approach 2: Manual feature engineering

# %%
def feature_engineering(X):
    feature = np.zeros((X.shape[0], 1))
    # Feature: (x1 - 0.5)*(x2 - 0.5) captures XOR pattern
    feature[:, 0] = (X[:, 0] - 0.5) * (X[:, 1] - 0.5)
    return np.hstack([X, feature])

X_2d_engineered = feature_engineering(X_2d)

# 3D plot of engineered features
plt.figure(figsize=(10, 8))
fig = plt.figure(figsize=(12, 10))
ax = fig.add_subplot(111, projection='3d')
ax.scatter(X_2d_engineered[y_2d == 0, 0], X_2d_engineered[y_2d == 0, 1], X_2d_engineered[y_2d == 0, 2], 
           c='blue', marker='o', label='Class 0')
ax.scatter(X_2d_engineered[y_2d == 1, 0], X_2d_engineered[y_2d == 1, 1], X_2d_engineered[y_2d == 1, 2], 
           c='red', marker='x', label='Class 1')
ax.set_xlabel('X₁')
ax.set_ylabel('X₂')
ax.set_zlabel('(X₁-0.5)(X₂-0.5)')
ax.set_title('XOR with Engineered Feature')
ax.legend()
plt.show()

def linear_model_with_engineered_features():
    model = Sequential([
        Dense(1, activation='sigmoid', input_shape=(3,))
    ])
    model.compile(optimizer=SGD(learning_rate=0.1), loss='binary_crossentropy', metrics=['accuracy'])
    model.fit(X_2d_engineered, y_2d, epochs=100, verbose=0)
    return model

engineered_model = linear_model_with_engineered_features()
engineered_predictions = (engineered_model.predict(X_2d_engineered) > 0.5).astype(int).flatten()
engineered_accuracy = accuracy_score(y_2d, engineered_predictions)
print(f"Linear model with engineered features accuracy: {engineered_accuracy:.4f}")
# Out:
# 7/7 [==============================] - 0s 1ms/step
# Linear model with engineered features accuracy: 0.8150

# %% [markdown]
# ### Approach 3: Shallow neural network (MLP with one hidden layer)

# %%
def shallow_neural_network():
    model = Sequential([
        Dense(4, activation='relu', input_shape=(2,)),
        Dense(1, activation='sigmoid')
    ])
    model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
    model.fit(X_2d, y_2d, epochs=100, verbose=0)
    return model

mlp_model = shallow_neural_network()
mlp_predictions = (mlp_model.predict(X_2d) > 0.5).astype(int).flatten()
mlp_accuracy = accuracy_score(y_2d, mlp_predictions)
print(f"Shallow neural network accuracy: {mlp_accuracy:.4f}")

plot_decision_boundary(mlp_model, X_2d, y_2d, f"MLP Decision Boundary (Accuracy: {mlp_accuracy:.4f})")
# Out:
# 7/7 [==============================] - 0s 987us/step
# Shallow neural network accuracy: 0.8150
# 113/113 [==============================] - 0s 719us/step

# %%
# Extending to explore higher dimensions
def explore_higher_dimensions():
    dimensions = range(3, 50)
    linear_accuracies = []
    engineered_accuracies = []
    mlp_accuracies = []
    
    for dim in dimensions:
        print(f"\nTraining models for {dim} dimensions...")
        X, y = generate_xor_data(n_samples=500, noise=0.05, dim=dim)
        
        # 1. Linear model
        linear = Sequential([
            Dense(1, activation='sigmoid', input_shape=(dim,))
        ])
        linear.compile(optimizer=SGD(learning_rate=0.1), loss='binary_crossentropy', metrics=['accuracy'])
        linear.fit(X, y, epochs=100, verbose=0)
        linear_pred = (linear.predict(X) > 0.5).astype(int).flatten()
        linear_acc = accuracy_score(y, linear_pred)
        linear_accuracies.append(linear_acc)
        
        # 2. Feature engineering
        X_eng = np.hstack([X, np.reshape((X[:, 0] - 0.5) * (X[:, 1] - 0.5), (-1, 1))])
        
        eng_model = Sequential([
            Dense(1, activation='sigmoid', input_shape=(dim+1,))
        ])
        eng_model.compile(optimizer=SGD(learning_rate=0.1), loss='binary_crossentropy', metrics=['accuracy'])
        eng_model.fit(X_eng, y, epochs=100, verbose=0)
        eng_pred = (eng_model.predict(X_eng) > 0.5).astype(int).flatten()
        eng_acc = accuracy_score(y, eng_pred)
        engineered_accuracies.append(eng_acc)
        
        # 3. MLP model
        # Adding more hidden units to increase capacity
        mlp = Sequential([
            Dense(4, activation='relu', input_shape=(dim,)),
            Dense(1, activation='sigmoid')
        ])
        mlp.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
        mlp.fit(X, y, epochs=100, verbose=0)
        mlp_pred = (mlp.predict(X) > 0.5).astype(int).flatten()
        mlp_acc = accuracy_score(y, mlp_pred)
        mlp_accuracies.append(mlp_acc)
        
        print(f"Dimension {dim}:")
        print(f"  Linear model accuracy: {linear_acc:.4f}")
        print(f"  Engineered features accuracy: {eng_acc:.4f}")
        print(f"  MLP accuracy: {mlp_acc:.4f}")
    
    # Plot results
    plt.figure(figsize=(12, 8))
    plt.plot(dimensions, linear_accuracies, 'o-', label='Linear Model')
    plt.plot(dimensions, engineered_accuracies, 's-', label='Feature Engineering')
    plt.plot(dimensions, mlp_accuracies, '^-', label='Shallow Neural Network')
    plt.xlabel('Number of Dimensions')
    plt.ylabel('Accuracy')
    plt.title('Model Performance vs. Dimensionality')
    plt.legend()
    plt.grid(True)
    plt.show()
    
    return dimensions, linear_accuracies, engineered_accuracies, mlp_accuracies

dimensions, linear_acc, engineered_acc, mlp_acc = explore_higher_dimensions()
# Out:
# Training models for 3 dimensions...
# 16/16 [==============================] - 0s 1ms/step
# 16/16 [==============================] - 0s 878us/step
# 16/16 [==============================] - 0s 1ms/step
# Dimension 3:
#   Linear model accuracy: 0.5120
#   Engineered features accuracy: 0.8280
#   MLP accuracy: 0.7120
#
# Training models for 4 dimensions...
# 16/16 [==============================] - 0s 1ms/step
# 16/16 [==============================] - 0s 839us/step
# 16/16 [==============================] - 0s 1ms/step
# Dimension 4:
#   Linear model accuracy: 0.5440
#   Engineered features accuracy: 0.7800
#   MLP accuracy: 0.5220
#
# Training models for 5 dimensions...
# 16/16 [==============================] - 0s 885us/step
# 16/16 [==============================] - 0s 635us/step
# 16/16 [==============================] - 0s 826us/step
# Dimension 5:
#   Linear model accuracy: 0.5300
#   Engineered features accuracy: 0.8260
#   MLP accuracy: 0.6520
#
# Training models for 6 dimensions...
# 16/16 [==============================] - 0s 772us/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 1ms/step
# Dimension 6:
#   Linear model accuracy: 0.5260
#   Engineered features accuracy: 0.7620
#   MLP accuracy: 0.6000
#
# Training models for 7 dimensions...
# 16/16 [==============================] - 0s 976us/step
# 16/16 [==============================] - 0s 1ms/step
# 16/16 [==============================] - 0s 779us/step
# Dimension 7:
#   Linear model accuracy: 0.5540
#   Engineered features accuracy: 0.8080
#   MLP accuracy: 0.6000
#
# Training models for 8 dimensions...
# 16/16 [==============================] - 0s 725us/step
# 16/16 [==============================] - 0s 866us/step
# 16/16 [==============================] - 0s 1ms/step
# Dimension 8:
#   Linear model accuracy: 0.5780
#   Engineered features accuracy: 0.7460
#   MLP accuracy: 0.6180
#
# Training models for 9 dimensions...
# 16/16 [==============================] - 0s 769us/step
# 16/16 [==============================] - 0s 932us/step
# 16/16 [==============================] - 0s 633us/step
# Dimension 9:
#   Linear model accuracy: 0.5700
#   Engineered features accuracy: 0.7460
#   MLP accuracy: 0.6660
#
# Training models for 10 dimensions...
# 16/16 [==============================] - 0s 615us/step
# 16/16 [==============================] - 0s 702us/step
# 16/16 [==============================] - 0s 922us/step
# Dimension 10:
#   Linear model accuracy: 0.5680
#   Engineered features accuracy: 0.7540
#   MLP accuracy: 0.6380
#
# Training models for 11 dimensions...
# 16/16 [==============================] - 0s 1ms/step
# 16/16 [==============================] - 0s 686us/step
# 16/16 [==============================] - 0s 928us/step
# Dimension 11:
#   Linear model accuracy: 0.5900
#   Engineered features accuracy: 0.7520
#   MLP accuracy: 0.6380
#
# Training models for 12 dimensions...
# 16/16 [==============================] - 0s 658us/step
# 16/16 [==============================] - 0s 752us/step
# 16/16 [==============================] - 0s 763us/step
# Dimension 12:
#   Linear model accuracy: 0.5440
#   Engineered features accuracy: 0.7480
#   MLP accuracy: 0.6200
#
# Training models for 13 dimensions...
# 16/16 [==============================] - 0s 940us/step
# 16/16 [==============================] - 0s 1ms/step
# 16/16 [==============================] - 0s 812us/step
# Dimension 13:
#   Linear model accuracy: 0.5540
#   Engineered features accuracy: 0.7580
#   MLP accuracy: 0.7240
#
# Training models for 14 dimensions...
# 16/16 [==============================] - 0s 788us/step
# 16/16 [==============================] - 0s 872us/step
# 16/16 [==============================] - 0s 829us/step
# Dimension 14:
#   Linear model accuracy: 0.5820
#   Engineered features accuracy: 0.7300
#   MLP accuracy: 0.6940
#
# Training models for 15 dimensions...
# 16/16 [==============================] - 0s 847us/step
# 16/16 [==============================] - 0s 733us/step
# 16/16 [==============================] - 0s 726us/step
# Dimension 15:
#   Linear model accuracy: 0.5520
#   Engineered features accuracy: 0.7820
#   MLP accuracy: 0.5740
#
# Training models for 16 dimensions...
# 16/16 [==============================] - 0s 830us/step
# 16/16 [==============================] - 0s 1ms/step
# 16/16 [==============================] - 0s 925us/step
# Dimension 16:
#   Linear model accuracy: 0.5900
#   Engineered features accuracy: 0.7520
#   MLP accuracy: 0.6880
#
# Training models for 17 dimensions...
# 16/16 [==============================] - 0s 701us/step
# 16/16 [==============================] - 0s 1ms/step
# 16/16 [==============================] - 0s 1ms/step
# Dimension 17:
#   Linear model accuracy: 0.5860
#   Engineered features accuracy: 0.7560
#   MLP accuracy: 0.6060
#
# Training models for 18 dimensions...
# 16/16 [==============================] - 0s 975us/step
# 16/16 [==============================] - 0s 807us/step
# 16/16 [==============================] - 0s 900us/step
# Dimension 18:
#   Linear model accuracy: 0.5960
#   Engineered features accuracy: 0.7180
#   MLP accuracy: 0.6040
#
# Training models for 19 dimensions...
# 16/16 [==============================] - 0s 802us/step
# 16/16 [==============================] - 0s 746us/step
# 16/16 [==============================] - 0s 1ms/step
# Dimension 19:
#   Linear model accuracy: 0.5840
#   Engineered features accuracy: 0.7460
#   MLP accuracy: 0.5980
#
# Training models for 20 dimensions...
# 16/16 [==============================] - 0s 1ms/step
# 16/16 [==============================] - 0s 920us/step
# 16/16 [==============================] - 0s 1ms/step
# Dimension 20:
#   Linear model accuracy: 0.5780
#   Engineered features accuracy: 0.7500
#   MLP accuracy: 0.6340
#
# Training models for 21 dimensions...
# 16/16 [==============================] - 0s 1ms/step
# 16/16 [==============================] - 0s 739us/step
# 16/16 [==============================] - 0s 849us/step
# Dimension 21:
#   Linear model accuracy: 0.5540
#   Engineered features accuracy: 0.7560
#   MLP accuracy: 0.7120
#
# Training models for 22 dimensions...
# 16/16 [==============================] - 0s 1ms/step
# 16/16 [==============================] - 0s 779us/step
# 16/16 [==============================] - 0s 876us/step
# Dimension 22:
#   Linear model accuracy: 0.6060
#   Engineered features accuracy: 0.7460
#   MLP accuracy: 0.6300
#
# Training models for 23 dimensions...
# 16/16 [==============================] - 0s 790us/step
# 16/16 [==============================] - 0s 833us/step
# 16/16 [==============================] - 0s 774us/step
# Dimension 23:
#   Linear model accuracy: 0.6000
#   Engineered features accuracy: 0.7440
#   MLP accuracy: 0.7060
#
# Training models for 24 dimensions...
# 16/16 [==============================] - 0s 890us/step
# 16/16 [==============================] - 0s 1ms/step
# 16/16 [==============================] - 0s 825us/step
# Dimension 24:
#   Linear model accuracy: 0.5640
#   Engineered features accuracy: 0.7280
#   MLP accuracy: 0.6060
#
# Training models for 25 dimensions...
# 16/16 [==============================] - 0s 779us/step
# 16/16 [==============================] - 0s 732us/step
# 16/16 [==============================] - 0s 819us/step
# Dimension 25:
#   Linear model accuracy: 0.5900
#   Engineered features accuracy: 0.7180
#   MLP accuracy: 0.6340
#
# Training models for 26 dimensions...
# 16/16 [==============================] - 0s 1ms/step
# 16/16 [==============================] - 0s 1ms/step
# 16/16 [==============================] - 0s 801us/step
# Dimension 26:
#   Linear model accuracy: 0.6160
#   Engineered features accuracy: 0.7380
#   MLP accuracy: 0.6260
#
# Training models for 27 dimensions...
# 16/16 [==============================] - 0s 859us/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 1ms/step
# Dimension 27:
#   Linear model accuracy: 0.6140
#   Engineered features accuracy: 0.7360
#   MLP accuracy: 0.6040
#
# Training models for 28 dimensions...
# 16/16 [==============================] - 0s 844us/step
# 16/16 [==============================] - 0s 736us/step
# 16/16 [==============================] - 0s 712us/step
# Dimension 28:
#   Linear model accuracy: 0.6260
#   Engineered features accuracy: 0.7320
#   MLP accuracy: 0.6400
#
# Training models for 29 dimensions...
# 16/16 [==============================] - 0s 1ms/step
# 16/16 [==============================] - 0s 922us/step
# 16/16 [==============================] - 0s 809us/step
# Dimension 29:
#   Linear model accuracy: 0.5840
#   Engineered features accuracy: 0.7460
#   MLP accuracy: 0.5720
#
# Training models for 30 dimensions...
# 16/16 [==============================] - 0s 866us/step
# 16/16 [==============================] - 0s 769us/step
# 16/16 [==============================] - 0s 824us/step
# Dimension 30:
#   Linear model accuracy: 0.5860
#   Engineered features accuracy: 0.7540
#   MLP accuracy: 0.6840
#
# Training models for 31 dimensions...
# 16/16 [==============================] - 0s 727us/step
# 16/16 [==============================] - 0s 904us/step
# 16/16 [==============================] - 0s 887us/step
# Dimension 31:
#   Linear model accuracy: 0.5560
#   Engineered features accuracy: 0.7240
#   MLP accuracy: 0.6840
#
# Training models for 32 dimensions...
# 16/16 [==============================] - 0s 739us/step
# 16/16 [==============================] - 0s 878us/step
# 16/16 [==============================] - 0s 1ms/step
# Dimension 32:
#   Linear model accuracy: 0.5740
#   Engineered features accuracy: 0.7700
#   MLP accuracy: 0.6260
#
# Training models for 33 dimensions...
# 16/16 [==============================] - 0s 725us/step
# 16/16 [==============================] - 0s 754us/step
# 16/16 [==============================] - 0s 738us/step
# Dimension 33:
#   Linear model accuracy: 0.6060
#   Engineered features accuracy: 0.7580
#   MLP accuracy: 0.6960
#
# Training models for 34 dimensions...
# 16/16 [==============================] - 0s 624us/step
# 16/16 [==============================] - 0s 846us/step
# 16/16 [==============================] - 0s 878us/step
# Dimension 34:
#   Linear model accuracy: 0.6260
#   Engineered features accuracy: 0.7480
#   MLP accuracy: 0.6780
#
# Training models for 35 dimensions...
# 16/16 [==============================] - 0s 730us/step
# 16/16 [==============================] - 0s 897us/step
# 16/16 [==============================] - 0s 1ms/step
# Dimension 35:
#   Linear model accuracy: 0.5840
#   Engineered features accuracy: 0.7460
#   MLP accuracy: 0.6280
#
# Training models for 36 dimensions...
# 16/16 [==============================] - 0s 735us/step
# 16/16 [==============================] - 0s 869us/step
# 16/16 [==============================] - 0s 1ms/step
# Dimension 36:
#   Linear model accuracy: 0.6380
#   Engineered features accuracy: 0.7520
#   MLP accuracy: 0.6440
#
# Training models for 37 dimensions...
# 16/16 [==============================] - 0s 837us/step
# 16/16 [==============================] - 0s 955us/step
# 16/16 [==============================] - 0s 910us/step
# Dimension 37:
#   Linear model accuracy: 0.6380
#   Engineered features accuracy: 0.7380
#   MLP accuracy: 0.6400
#
# Training models for 38 dimensions...
# 16/16 [==============================] - 0s 818us/step
# 16/16 [==============================] - 0s 885us/step
# 16/16 [==============================] - 0s 958us/step
# Dimension 38:
#   Linear model accuracy: 0.6100
#   Engineered features accuracy: 0.7600
#   MLP accuracy: 0.6420
#
# Training models for 39 dimensions...
# 16/16 [==============================] - 0s 833us/step
# 16/16 [==============================] - 0s 972us/step
# 16/16 [==============================] - 0s 890us/step
# Dimension 39:
#   Linear model accuracy: 0.5840
#   Engineered features accuracy: 0.7380
#   MLP accuracy: 0.6380
#
# Training models for 40 dimensions...
# 16/16 [==============================] - 0s 741us/step
# 16/16 [==============================] - 0s 665us/step
# 16/16 [==============================] - 0s 789us/step
# Dimension 40:
#   Linear model accuracy: 0.5900
#   Engineered features accuracy: 0.7320
#   MLP accuracy: 0.6000
#
# Training models for 41 dimensions...
# 16/16 [==============================] - 0s 958us/step
# 16/16 [==============================] - 0s 944us/step
# 16/16 [==============================] - 0s 935us/step
# Dimension 41:
#   Linear model accuracy: 0.6380
#   Engineered features accuracy: 0.7400
#   MLP accuracy: 0.6500
#
# Training models for 42 dimensions...
# 16/16 [==============================] - 0s 696us/step
# 16/16 [==============================] - 0s 905us/step
# 16/16 [==============================] - 0s 783us/step
# Dimension 42:
#   Linear model accuracy: 0.6000
#   Engineered features accuracy: 0.7360
#   MLP accuracy: 0.7200
#
# Training models for 43 dimensions...
# 16/16 [==============================] - 0s 1ms/step
# 16/16 [==============================] - 0s 1ms/step
# 16/16 [==============================] - 0s 854us/step
# Dimension 43:
#   Linear model accuracy: 0.6220
#   Engineered features accuracy: 0.7320
#   MLP accuracy: 0.6400
#
# Training models for 44 dimensions...
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 1ms/step
# 16/16 [==============================] - 0s 2ms/step
# Dimension 44:
#   Linear model accuracy: 0.6140
#   Engineered features accuracy: 0.7240
#   MLP accuracy: 0.6380
#
# Training models for 45 dimensions...
# 16/16 [==============================] - 0s 923us/step
# 16/16 [==============================] - 0s 707us/step
# 16/16 [==============================] - 0s 2ms/step
# Dimension 45:
#   Linear model accuracy: 0.6160
#   Engineered features accuracy: 0.7260
#   MLP accuracy: 0.6100
#
# Training models for 46 dimensions...
# 16/16 [==============================] - 0s 1ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# Dimension 46:
#   Linear model accuracy: 0.6300
#   Engineered features accuracy: 0.7260
#   MLP accuracy: 0.6740
#
# Training models for 47 dimensions...
# 16/16 [==============================] - 0s 735us/step
# 16/16 [==============================] - 0s 917us/step
# 16/16 [==============================] - 0s 799us/step
# Dimension 47:
#   Linear model accuracy: 0.6160
#   Engineered features accuracy: 0.7240
#   MLP accuracy: 0.6280
#
# Training models for 48 dimensions...
# 16/16 [==============================] - 0s 603us/step
# 16/16 [==============================] - 0s 801us/step
# 16/16 [==============================] - 0s 886us/step
# Dimension 48:
#   Linear model accuracy: 0.5800
#   Engineered features accuracy: 0.7260
#   MLP accuracy: 0.6540
#
# Training models for 49 dimensions...
# 16/16 [==============================] - 0s 737us/step
# 16/16 [==============================] - 0s 798us/step
# 16/16 [==============================] - 0s 1ms/step
# Dimension 49:
#   Linear model accuracy: 0.6220
#   Engineered features accuracy: 0.7380
#   MLP accuracy: 0.6460

# %% [markdown]
# ### Result Analysis

# %%
print("\n=== Final Analysis ===")
print("Performance Summary:")
for i, dim in enumerate(dimensions):
    print(f"Dimension {dim}:")
    print(f"  Linear model: {linear_acc[i]:.4f}")
    print(f"  Feature engineering: {engineered_acc[i]:.4f}")
    print(f"  Neural network: {mlp_acc[i]:.4f}")
    print()
# Out:
# === Final Analysis ===
# Performance Summary:
# Dimension 3:
#   Linear model: 0.5120
#   Feature engineering: 0.8280
#   Neural network: 0.7120
#
# Dimension 4:
#   Linear model: 0.5440
#   Feature engineering: 0.7800
#   Neural network: 0.5220
#
# Dimension 5:
#   Linear model: 0.5300
#   Feature engineering: 0.8260
#   Neural network: 0.6520
#
# Dimension 6:
#   Linear model: 0.5260
#   Feature engineering: 0.7620
#   Neural network: 0.6000
#
# Dimension 7:
#   Linear model: 0.5540
#   Feature engineering: 0.8080
#   Neural network: 0.6000
#
# Dimension 8:
#   Linear model: 0.5780
#   Feature engineering: 0.7460
#   Neural network: 0.6180
#
# Dimension 9:
#   Linear model: 0.5700
#   Feature engineering: 0.7460
#   Neural network: 0.6660
#
# Dimension 10:
#   Linear model: 0.5680
#   Feature engineering: 0.7540
#   Neural network: 0.6380
#
# Dimension 11:
#   Linear model: 0.5900
#   Feature engineering: 0.7520
#   Neural network: 0.6380
#
# Dimension 12:
#   Linear model: 0.5440
#   Feature engineering: 0.7480
#   Neural network: 0.6200
#
# Dimension 13:
#   Linear model: 0.5540
#   Feature engineering: 0.7580
#   Neural network: 0.7240
#
# Dimension 14:
#   Linear model: 0.5820
#   Feature engineering: 0.7300
#   Neural network: 0.6940
#
# Dimension 15:
#   Linear model: 0.5520
#   Feature engineering: 0.7820
#   Neural network: 0.5740
#
# Dimension 16:
#   Linear model: 0.5900
#   Feature engineering: 0.7520
#   Neural network: 0.6880
#
# Dimension 17:
#   Linear model: 0.5860
#   Feature engineering: 0.7560
#   Neural network: 0.6060
#
# Dimension 18:
#   Linear model: 0.5960
#   Feature engineering: 0.7180
#   Neural network: 0.6040
#
# Dimension 19:
#   Linear model: 0.5840
#   Feature engineering: 0.7460
#   Neural network: 0.5980
#
# Dimension 20:
#   Linear model: 0.5780
#   Feature engineering: 0.7500
#   Neural network: 0.6340
#
# Dimension 21:
#   Linear model: 0.5540
#   Feature engineering: 0.7560
#   Neural network: 0.7120
#
# Dimension 22:
#   Linear model: 0.6060
#   Feature engineering: 0.7460
#   Neural network: 0.6300
#
# Dimension 23:
#   Linear model: 0.6000
#   Feature engineering: 0.7440
#   Neural network: 0.7060
#
# Dimension 24:
#   Linear model: 0.5640
#   Feature engineering: 0.7280
#   Neural network: 0.6060
#
# Dimension 25:
#   Linear model: 0.5900
#   Feature engineering: 0.7180
#   Neural network: 0.6340
#
# Dimension 26:
#   Linear model: 0.6160
#   Feature engineering: 0.7380
#   Neural network: 0.6260
#
# Dimension 27:
#   Linear model: 0.6140
#   Feature engineering: 0.7360
#   Neural network: 0.6040
#
# Dimension 28:
#   Linear model: 0.6260
#   Feature engineering: 0.7320
#   Neural network: 0.6400
#
# Dimension 29:
#   Linear model: 0.5840
#   Feature engineering: 0.7460
#   Neural network: 0.5720
#
# Dimension 30:
#   Linear model: 0.5860
#   Feature engineering: 0.7540
#   Neural network: 0.6840
#
# Dimension 31:
#   Linear model: 0.5560
#   Feature engineering: 0.7240
#   Neural network: 0.6840
#
# Dimension 32:
#   Linear model: 0.5740
#   Feature engineering: 0.7700
#   Neural network: 0.6260
#
# Dimension 33:
#   Linear model: 0.6060
#   Feature engineering: 0.7580
#   Neural network: 0.6960
#
# Dimension 34:
#   Linear model: 0.6260
#   Feature engineering: 0.7480
#   Neural network: 0.6780
#
# Dimension 35:
#   Linear model: 0.5840
#   Feature engineering: 0.7460
#   Neural network: 0.6280
#
# Dimension 36:
#   Linear model: 0.6380
#   Feature engineering: 0.7520
#   Neural network: 0.6440
#
# Dimension 37:
#   Linear model: 0.6380
#   Feature engineering: 0.7380
#   Neural network: 0.6400
#
# Dimension 38:
#   Linear model: 0.6100
#   Feature engineering: 0.7600
#   Neural network: 0.6420
#
# Dimension 39:
#   Linear model: 0.5840
#   Feature engineering: 0.7380
#   Neural network: 0.6380
#
# Dimension 40:
#   Linear model: 0.5900
#   Feature engineering: 0.7320
#   Neural network: 0.6000
#
# Dimension 41:
#   Linear model: 0.6380
#   Feature engineering: 0.7400
#   Neural network: 0.6500
#
# Dimension 42:
#   Linear model: 0.6000
#   Feature engineering: 0.7360
#   Neural network: 0.7200
#
# Dimension 43:
#   Linear model: 0.6220
#   Feature engineering: 0.7320
#   Neural network: 0.6400
#
# Dimension 44:
#   Linear model: 0.6140
#   Feature engineering: 0.7240
#   Neural network: 0.6380
#
# Dimension 45:
#   Linear model: 0.6160
#   Feature engineering: 0.7260
#   Neural network: 0.6100
#
# Dimension 46:
#   Linear model: 0.6300
#   Feature engineering: 0.7260
#   Neural network: 0.6740
#
# Dimension 47:
#   Linear model: 0.6160
#   Feature engineering: 0.7240
#   Neural network: 0.6280
#
# Dimension 48:
#   Linear model: 0.5800
#   Feature engineering: 0.7260
#   Neural network: 0.6540
#
# Dimension 49:
#   Linear model: 0.6220
#   Feature engineering: 0.7380
#   Neural network: 0.6460
